# %%
import pandas as pd
 
# to read csv file named "samplee"
a = pd.read_csv("../resources/movies_adjusted.csv")

# %%
 
# to save as html file
# named as "Table"
a.to_html("movie_data.html")
 
# assign it to a
# variable (string)
movie_data = a.to_html()

# %%
movie_data
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>year</th>\n      <th>title</th>\n      <th>director</th>\n      <th>writer</th>\n      <th>mpaa</th>\n      <th>main_actor_1</th>\n      <th>main_actor_2</th>\n      <th>main_actor_3</th>\n      <th>main_actor_4</th>\n      <th>genre_1</th>\n      <th>genre_2</th>\n      <th>genre_3</th>\n      <th>genre_4</th>\n      <th>Adjusted Worldwide</th>\n      <th>Adjusted Domestic</th>\n      <th>Adjusted International</th>\n      <th>Adjusted Budget</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>1990</td>\n      <td>Back to the Future Part III</td>\n      <td>Robert Zemeckis</td>\n      <td>Robert Zemeckis</td>\n      <td>NaN</td>\n      <td>Michael J. Fox</td>\n      <td>Christopher Lloyd</td>\n      <td>Mary Steenburgen</td>\n      <td>Thomas F. Wilson</td>\n      <td>Adventure</td>\n      <td>Comedy<
# ...
